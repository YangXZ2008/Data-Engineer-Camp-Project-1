# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_fuel = pd.read_csv("fuel_prices.csv")
df_station = pd.read_csv("stations.csv")

# %%
df_fuel.shape
# Out:
# (10077, 6)

# %%
df_fuel.dtypes
# Out:
# Unnamed: 0       int64
# stationcode      int64
# state           object
# fueltype        object
# price          float64
# lastupdated     object
# dtype: object

# %%
df_station.iloc[100: 200]
# Out:
#      Unnamed: 0  brandid  stationid        brand  code  \
# 100         100      NaN        NaN       United  2360
# 101         101      NaN        NaN        Ampol  2362
# 102         102      NaN        NaN   Metro Fuel  2363
# 103         103      NaN        NaN        Ampol  2364
# 104         104      NaN        NaN  Independent  2366
# ..          ...      ...        ...          ...   ...
# 195         195      NaN        NaN  Independent  2694
# 196         196      NaN        NaN        Mobil  2695
# 197         197      NaN        NaN           BP  2696
# 198         198      NaN        NaN        Ampol  2697
# 199         199      NaN        NaN  Independent  2701
#
#                             name  \
# 100            United Bulahdelah
# 101            Ampol Carlingford
# 102               Metro Tuggerah
# 103  Ampol Woolworths Kellyville
# 104    Invergowrie General Store
# ..                           ...
# 195                  Access Fuel
# ...

# %%
df_station.dtypes
# Out:
# Unnamed: 0              int64
# brandid               float64
# stationid             float64
# brand                  object
# code                    int64
# name                   object
# address                object
# state                  object
# location.latitude     float64
# location.longitude    float64
# dtype: object
